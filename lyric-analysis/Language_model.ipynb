# %%
from textgenrnn import textgenrnn
# Out:
# Using TensorFlow backend.

# %%
textgen = textgenrnn()

# %% [markdown]
# Change the file name to any of the lyrics files generated by 'Naive Analysis' notebook

# %%
file_path = "hiphop.txt"
textgen.reset()
textgen.train_from_file(file_path,
                        num_epochs = 1)
# Out:
# 115 texts collected.
# Training on 6,687 character sequences.
# Epoch 1/1
# 52/52 [==============================] - 2s 46ms/step - loss: 2.2270
# ####################
# Temperature: 0.2
# ####################
# I got that shows the dream that what havin the so sick and havin the shit on my boy. Im a show in a shit of my party, and I got that you show you show you show you sick you show you got the so me the so here that the so me full home on the sime and I got that the drunkey in the punk and I got the
#
# I gotta the put the put the pose on the put the shit of a bass and the punk that the so here that the sister and the shit so me for the hours and I got the pose and I gotta to the punk and you show you got the pose on the put the shit on the so here and I got the pose for the drunkers the drunk an
#
# ...

# %%
textgen.generate(interactive = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3b0096d7a06b> in <module>()
# ----> 1 textgen.generate(interactive = True)
#
# NameError: name 'textgen' is not defined
